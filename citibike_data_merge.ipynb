# %%
import pandas as pd
import csv

# %%
filepath = "Raw Data/JC-202101-citibike-tripdata.csv"
df_JC_202101 = pd.read_csv(filepath)

filepath2 = "Raw Data/202101-citibike-tripdata.csv"
df_202101 = pd.read_csv(filepath2)

# %%
df_202101.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2513  2021-01-01 00:00:11.9020  2021-01-01 00:42:05.2260
# 1          2519  2021-01-01 00:00:15.0960  2021-01-01 00:42:14.9780
# 2          1207  2021-01-01 00:00:28.9300  2021-01-01 00:20:36.6510
# 3          2506  2021-01-01 00:00:32.7130  2021-01-01 00:42:19.3980
# 4           959  2021-01-01 00:00:35.3650  2021-01-01 00:16:34.6010
#
#    start station id          start station name  start station latitude  \
# 0              3581  Underhill Ave & Lincoln Pl               40.674012
# 1              3581  Underhill Ave & Lincoln Pl               40.674012
# 2              3144          E 81 St & Park Ave               40.776777
# 3              3581  Underhill Ave & Lincoln Pl               40.674012
# 4               534     Water - Whitehall Plaza               40.702551
#
#    start station longitude  end station id            end station name  \
# ...

# %%
df_JC_202101.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1          1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2          1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3           793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4           596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
#
#    start station id start station name  start station latitude  \
# 0              3273       Manila & 1st               40.721651
# 1              3681           Grand St               40.715178
# 2              3681           Grand St               40.715178
# 3              3185          City Hall               40.717733
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.042884            3209     Brunswick St
# ...

# %%
df_list = [df_JC_202101, df_202101]
df_concat_202101 = pd.concat(df_list)
df_concat_202101
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1                1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2                1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3                 793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4                 596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...               ...                       ...                       ...
# 1095341           569  2021-01-31 23:54:00.3610  2021-02-01 00:03:29.8190
# 1095342          1439  2021-01-31 23:55:50.4170  2021-02-01 00:19:49.8980
# 1095343          2619  2021-01-31 23:56:14.9540  2021-02-01 00:39:54.3500
# 1095344            83  2021-01-31 23:59:19.8260  2021-02-01 00:00:43.5840
# 1095345          1313  2021-01-31 23:59:40.4440  2021-02-01 00:21:33.8470
#
#          start station id         start station name  start station latitude  \
# ...

# %%
df_JC_202101.describe()
# Out:
#         tripduration  start station id  start station latitude  \
# count   11624.000000      11624.000000            11624.000000
# mean      985.140571       3299.824673               40.722745
# std      9907.868836        177.102119                0.007203
# min        61.000000       3184.000000               40.711130
# 25%       271.000000       3195.000000               40.717733
# 50%       443.500000       3210.000000               40.721630
# 75%       797.000000       3276.000000               40.727224
# max    760684.000000       3792.000000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count             11624.000000    11624.000000          11624.000000
# mean                -74.047279     3298.063575             40.722357
# std                   0.011707      178.562559              0.007211
# min                 -74.083639      514.000000             40.711130
# ...

# %%
df_202101.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.095346e+06      1.095346e+06            1.095346e+06
# mean   9.339377e+02      2.132498e+03            4.074246e+01
# std    7.933943e+03      1.561416e+03            3.544283e-02
# min    6.100000e+01      7.200000e+01            4.064451e+01
# 25%    3.310000e+02      4.380000e+02            4.071882e+01
# 50%    5.800000e+02      3.129000e+03            4.074268e+01
# 75%    1.032000e+03      3.526000e+03            4.076548e+01
# max    2.140110e+06      4.387000e+03            4.085225e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.095346e+06    1.095346e+06          1.095346e+06
# mean             -7.397627e+01    2.129096e+03          4.074219e+01
# std               2.275544e-02    1.561959e+03          3.528590e-02
# min              -7.402309e+01    7.200000e+01          4.064451e+01
# ...

# %%
df_concat_202101.to_csv("Raw Data/JC_NY_202101.csv")
